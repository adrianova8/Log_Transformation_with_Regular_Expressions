# %% [markdown]
# <a href="https://colab.research.google.com/github/adrianova8/Log_Transformation_with_Regular_Expressions/blob/main/S05_T01_Transformaci%C3%B3_Registre_Log_amb_Regular_expressions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title ITINERARIO DATA SCIENCE - IT ACADEMY 
from IPython.display import Image
Image('/content/drive/MyDrive/IT Academy - Data Science/SPRINT 5 - Altres mòduls bàsics de Python/DataScience.png')

# %% [markdown]
# <div class="alert alert-block alert-info"><font size="6"><center><b><u>Sprint 5. Other basic Python modules</u></b></center></font>
#
# \begin{align*}Adrià\:Nova\end{align*}
#
# \begin{align*}Data\hspace{2mm}Science\hspace{2mm}Integrator\end{align*}
#
# \begin{align*}Date : November\hspace{2mm}2021\end{align*}</div>

# %% [markdown]
# <h1>S05 T01 Transformació Registre Log amb Regular expressions<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Exercise-1" data-toc-modified-id="Exercise-1-1"><span style="color: gray"><ins>Exercise 1</ins></span></a></span></li><li><span><a href="#Exercise-3" data-toc-modified-id="Exercise-3-2"><span style="color: gray"><ins>Exercise 3</ins></span></a></span></li></ul></div>

# %% [markdown]
# # <ins>Exercise 1</ins>

# %%
# We import 

import pandas as pd

pd.set_option('display.max_colwidth', None)
data = pd.read_csv('/content/drive/MyDrive/IT Academy - Data Science/SPRINT 5 - Altres mòduls bàsics de Python/Web_access_log-akumenius.txt',names=["Unique_Colum"])
data.head()
# Out:
#                                                                                                                       Unique_Colum
# 0  localhost 127.0.0.1 - - [23/Feb/2014:03:10:31 +0100] "OPTIONS * HTTP/1.0" 200 - "-" "Apache (internal dummy connection)" VLOG=-
# 1  localhost 127.0.0.1 - - [23/Feb/2014:03:10:31 +0100] "OPTIONS * HTTP/1.0" 200 - "-" "Apache (internal dummy connection)" VLOG=-
# 2  localhost 127.0.0.1 - - [23/Feb/2014:03:10:31 +0100] "OPTIONS * HTTP/1.0" 200 - "-" "Apache (internal dummy connection)" VLOG=-
# 3  localhost 127.0.0.1 - - [23/Feb/2014:03:10:31 +0100] "OPTIONS * HTTP/1.0" 200 - "-" "Apache (internal dummy connection)" VLOG=-
# 4  localhost 127.0.0.1 - - [23/Feb/2014:03:10:31 +0100] "OPTIONS * HTTP/1.0" 200 - "-" "Apache (internal dummy connection)" VLOG=-
